# %%
# %cd /content/drive/My Drive/time_series_analysis/time_series_prediction
# Out:
# [Errno 2] No such file or directory: '/content/drive/My Drive/time_series_analysis/time_series_prediction'
# /content

# %%
# !git status

# %%
# !git add .

# %%
# !git config --global user.email "katarzyna.staniewicz0504@gmail.com"

# %%
# !git commit -m 'Updates'

# %%
# !git push
